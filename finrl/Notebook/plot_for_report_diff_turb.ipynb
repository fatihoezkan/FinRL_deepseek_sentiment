# %%
import pandas as pd



def load_data():
    df = pd.read_csv('/Users/fatihozkan/Desktop/finrl-deepseek-stock-prediction-fatih_clean/results.csv')
    df['date'] = pd.to_datetime(df['date'])
    df = df.set_index('date').reset_index()
    df['A2C % Diff'] = 100 * (df["A2C Agent 2"] - df["A2C Agent 1"]) / df["A2C Agent 1"]
    df['SAC % Diff'] = 100 * (df["SAC Agent 2"] - df["SAC Agent 1"]) / df["SAC Agent 1"]
    df['PPO % Diff'] = 100 * (df["PPO Agent 2"] - df["PPO Agent 1"]) / df["PPO Agent 1"]
    df['TD3 % Diff'] = 100 * (df["TD3 Agent 2"] - df["TD3 Agent 1"]) / df["TD3 Agent 1"]
    df['A2C % Diff 3'] = 100 * (df["A2C Agent 3"] - df["A2C Agent 1"]) / df["A2C Agent 1"]
    df['SAC % Diff 3'] = 100 * (df["SAC Agent 3"] - df["SAC Agent 1"]) / df["SAC Agent 1"]
    df['PPO % Diff 3'] = 100 * (df["PPO Agent 3"] - df["PPO Agent 1"]) / df["PPO Agent 1"]
    df['TD3 % Diff 3'] = 100 * (df["TD3 Agent 3"] - df["TD3 Agent 1"]) / df["TD3 Agent 1"]
    return df

df = load_data()

df
# Out:
#                          date   A2C Agent 1   A2C Agent 2   A2C Agent 3  \
# 0   2025-02-21 14:30:00+00:00  1.000000e+06  1.000000e+06  1.000000e+06
# 1   2025-02-21 15:30:00+00:00  1.000000e+06  1.000000e+06  1.000000e+06
# 2   2025-02-21 16:30:00+00:00  1.000000e+06  1.000000e+06  1.000000e+06
# 3   2025-02-21 17:30:00+00:00  1.000000e+06  1.000000e+06  1.000000e+06
# 4   2025-02-21 18:30:00+00:00  1.000000e+06  1.000000e+06  1.000000e+06
# ..                        ...           ...           ...           ...
# 562 2025-06-17 15:30:00+00:00  1.107584e+06  1.223275e+06  2.140591e+06
# 563 2025-06-17 16:30:00+00:00  1.106133e+06  1.221672e+06  2.137787e+06
# 564 2025-06-17 17:30:00+00:00  1.101169e+06  1.216189e+06  2.128192e+06
# 565 2025-06-17 18:30:00+00:00  1.101903e+06  1.217000e+06  2.129611e+06
# 566 2025-06-17 19:30:00+00:00  1.100100e+06  1.215008e+06  2.126126e+06
#
#       SAC Agent 1   SAC Agent 2   SAC Agent 3   PPO Agent 1   PPO Agent 2  \
# 0    1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 1    1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 2    1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 3    1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# 4    1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06  1.000000e+06
# ..            ...           ...           ...           ...           ...
# 562  1.106275e+06  1.225529e+06  1.873620e+06  1.107815e+06  1.237550e+06
# 563  1.104826e+06  1.223923e+06  1.871166e+06  1.106364e+06  1.235929e+06
# 564  1.099867e+06  1.218431e+06  1.862768e+06  1.101398e+06  1.230382e+06
# 565  1.100600e+06  1.219243e+06  1.864010e+06  1.102132e+06  1.231202e+06
# 566  1.098799e+06  1.217248e+06  1.860959e+06  1.100329e+06  1.229188e+06
#
#       PPO Agent 3  ...           mvo            djia  A2C % Diff  SAC % Diff  \
# 0    1.000000e+06  ...  9.370239e+05  1000000.000000    0.000000    0.000000
# 1    1.000000e+06  ...  9.370239e+05   999981.718120    0.000000    0.000000
# 2    1.000000e+06  ...  9.370239e+05   998114.469359    0.000000    0.000000
# 3    1.000000e+06  ...  9.370239e+05   992950.953106    0.000000    0.000000
# 4    1.000000e+06  ...  9.370239e+05   990121.185675    0.000000    0.000000
# ..            ...  ...           ...             ...         ...         ...
# 562  2.091263e+06  ...  1.005827e+06   969370.271292   10.445327   10.779772
# 563  2.088523e+06  ...  1.004509e+06   965804.948040   10.445322   10.779777
# 564  2.079150e+06  ...  1.000001e+06   962930.858199   10.445304   10.779794
# 565  2.080536e+06  ...  1.000667e+06   964135.321938   10.445307   10.779791
# 566  2.077131e+06  ...  9.990296e+05   963681.039524   10.445301   10.779797
#
#      PPO % Diff  TD3 % Diff  A2C % Diff 3  SAC % Diff 3  PPO % Diff 3  \
# 0      0.000000    0.000000      0.000000      0.000000      0.000000
# 1      0.000000    0.000000      0.000000      0.000000      0.000000
# 2      0.000000    0.000000      0.000000      0.000000      0.000000
# 3      0.000000    0.000000      0.000000      0.000000      0.000000
# 4      0.000000    0.000000      0.000000      0.000000      0.000000
# ..          ...         ...           ...           ...           ...
# 562   11.710899   10.779772     93.266706     69.362966     88.773654
# 563   11.710909   10.779777     93.266702     69.362966     88.773661
# 564   11.710944   10.779794     93.266689     69.362967     88.773686
# 565   11.710939   10.779791     93.266691     69.362967     88.773682
# 566   11.710952   10.779797     93.266686     69.362967     88.773691
#
#      TD3 % Diff 3
# 0        0.000000
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# ..            ...
# 562     69.362966
# 563     69.362966
# 564     69.362967
# 565     69.362967
# 566     69.362967
#
# [567 rows x 23 columns]

# %%
import matplotlib.pyplot as plt

# plot agent1 agent 2 and agent 3 results only only A2C and SAC
df.plot(x='date', y=['A2C Agent 1', 'A2C Agent 2', 'A2C Agent 3', 'SAC Agent 1', 'SAC Agent 2', 'SAC Agent 3'], figsize=(10, 5), title='Agent 1 vs Agent 2 vs Agent 3 Results (A2C and SAC)')
# Out:
# <Axes: title={'center': 'Agent 1 vs Agent 2 vs Agent 3 Results (A2C and SAC)'}, xlabel='date'>
